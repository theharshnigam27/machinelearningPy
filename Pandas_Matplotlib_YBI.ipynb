# %%
# step1: Import library
import pandas as pd

# %%
# Step 2: Import data
df = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv')

# %%
import pandas as pd

# %%
titanic = pd.read_excel('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.xlsx')

# %% [markdown]
# **Explore the data**

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
df.sample(4)
# Out:
#       pclass  survived                                      name     sex  age  \
# 1163       3         0                         Ryan, Mr. Patrick    male  NaN
# 125        1         0                          Fry, Mr. Richard    male  NaN
# 843        3         0      Hagland, Mr. Konrad Mathias Reiersen    male  NaN
# 901        3         0  Johnston, Miss. Catherine Helen "Carrie"  female  NaN
#
#       sibsp  parch      ticket     fare cabin embarked boat  body home.dest
# 1163      0      0      371110  24.1500   NaN        Q  NaN   NaN       NaN
# 125       0      0      112058   0.0000  B102        S  NaN   NaN       NaN
# 843       1      0       65304  19.9667   NaN        S  NaN   NaN       NaN
# 901       1      2  W./C. 6607  23.4500   NaN        S  NaN   NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
True + True
# Out:
# 2

# %%
True + True + False + True + False
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
df.describe(include='all')
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881138
# std        0.837836     0.486055                   NaN   NaN    14.413493
# min        1.000000     0.000000                   NaN   NaN     0.170000
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
df.shape
# Out:
# (1309, 14)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.fare
# Out:
# 0       211.3375
# 1       151.5500
# 2       151.5500
# 3       151.5500
# 4       151.5500
#           ...
# 1304     14.4542
# 1305     14.4542
# 1306      7.2250
# 1307      7.2250
# 1308      7.8750
# Name: fare, Length: 1309, dtype: float64

# %%
df['fare']
# Out:
# 0       211.3375
# 1       151.5500
# 2       151.5500
# 3       151.5500
# 4       151.5500
#           ...
# 1304     14.4542
# 1305     14.4542
# 1306      7.2250
# 1307      7.2250
# 1308      7.8750
# Name: fare, Length: 1309, dtype: float64

# %%
admission = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Admission%20Chance.csv')

# %%
admission.columns  #See 'LOR ' it has a extra space.
# Out:
# Index(['Serial No', 'GRE Score', 'TOEFL Score', 'University Rating', ' SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
#So, admission.LOR will not work instaed of using that, use admission['LOR']
admission.LOR
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1ba14458b276> in <cell line: 2>()
#       1 #So, admission.LOR will not work instaed of using that, use admission['LOR']
# ----> 2 admission.LOR
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'LOR'

# %%
admission['LOR ']
# Out:
# 0      4.5
# 1      4.5
# 2      3.5
# 3      2.5
# 4      3.0
#       ...
# 395    3.5
# 396    3.5
# 397    4.5
# 398    4.0
# 399    4.0
# Name: LOR , Length: 400, dtype: float64

# %%
col1 = df['fare']

# %%
col1.shape
# Out:
# (1309,)

# %%
col2 = df[['fare']]

# %%
col2
# Out:
#           fare
# 0     211.3375
# 1     151.5500
# 2     151.5500
# 3     151.5500
# 4     151.5500
# ...        ...
# 1304   14.4542
# 1305   14.4542
# 1306    7.2250
# 1307    7.2250
# 1308    7.8750
#
# [1309 rows x 1 columns]

# %%
col2.shape
# Out:
# (1309, 1)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df[['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
       'fare', 'cabin', 'embarked', 'boat', 'body']]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.iloc[:,:]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.loc[:,:]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.loc[0:3,]
# Out:
#    pclass  survived                                  name     sex    age  \
# 0       1         1         Allen, Miss. Elisabeth Walton  female  29.00
# 1       1         1        Allison, Master. Hudson Trevor    male   0.92
# 2       1         0          Allison, Miss. Helen Loraine  female   2.00
# 3       1         0  Allison, Mr. Hudson Joshua Creighton    male  30.00
#
#    sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      0      0   24160  211.3375       B5        S    2    NaN
# 1      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      1      2  113781  151.5500  C22 C26        S  NaN  135.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
df.iloc[0:3,]
# Out:
#    pclass  survived                            name     sex    age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.00      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.92      1
# 2       1         0    Allison, Miss. Helen Loraine  female   2.00      1
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0      0   24160  211.3375       B5        S    2   NaN
# 1      2  113781  151.5500  C22 C26        S   11   NaN
# 2      2  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
df.iloc[0:3:,0:3]
# Out:
#    pclass  survived                            name
# 0       1         1   Allen, Miss. Elisabeth Walton
# 1       1         1  Allison, Master. Hudson Trevor
# 2       1         0    Allison, Miss. Helen Loraine

# %%
df.loc[0:3,'pclass':'name']
# Out:
#    pclass  survived                                  name
# 0       1         1         Allen, Miss. Elisabeth Walton
# 1       1         1        Allison, Master. Hudson Trevor
# 2       1         0          Allison, Miss. Helen Loraine
# 3       1         0  Allison, Mr. Hudson Joshua Creighton

# %%
df.loc[1304:1306,'pclass':'name']
# Out:
#       pclass  survived                       name
# 1304       3         0       Zabour, Miss. Hileni
# 1305       3         0      Zabour, Miss. Thamine
# 1306       3         0  Zakarian, Mr. Mapriededer

# %%
df.iloc[1304:1307,0:3]
# Out:
#       pclass  survived                       name
# 1304       3         0       Zabour, Miss. Hileni
# 1305       3         0      Zabour, Miss. Thamine
# 1306       3         0  Zakarian, Mr. Mapriededer

# %%
df.loc[[1304,1306],'pclass':'name']
# Out:
#       pclass  survived                       name
# 1304       3         0       Zabour, Miss. Hileni
# 1306       3         0  Zakarian, Mr. Mapriededer

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.drop('pclass',axis=1)
# Out:
#       survived                                             name     sex  \
# 0            1                    Allen, Miss. Elisabeth Walton  female
# 1            1                   Allison, Master. Hudson Trevor    male
# 2            0                     Allison, Miss. Helen Loraine  female
# 3            0             Allison, Mr. Hudson Joshua Creighton    male
# 4            0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...        ...                                              ...     ...
# 1304         0                             Zabour, Miss. Hileni  female
# 1305         0                            Zabour, Miss. Thamine  female
# 1306         0                        Zakarian, Mr. Mapriededer    male
# 1307         0                              Zakarian, Mr. Ortin    male
# 1308         0                               Zimmerman, Mr. Leo    male
#
#         age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %%
df.drop(['pclass','survived'],axis=1)
# Out:
#                                                  name     sex    age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.00      0
# 1                      Allison, Master. Hudson Trevor    male   0.92      1
# 2                        Allison, Miss. Helen Loraine  female   2.00      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# ...                                               ...     ...    ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50      1
# 1305                            Zabour, Miss. Thamine  female    NaN      1
# 1306                        Zakarian, Mr. Mapriededer    male  26.50      0
# 1307                              Zakarian, Mr. Ortin    male  27.00      0
# 1308                               Zimmerman, Mr. Leo    male  29.00      0
#
# ...

# %%
df['age']
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305      NaN
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
df['age']<=30
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1304     True
# 1305    False
# 1306     True
# 1307     True
# 1308     True
# Name: age, Length: 1309, dtype: bool

# %%
df.loc[df['age']<=30,:]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.loc[df['age']<=30,['name','fare']]
# Out:
#                                                  name      fare
# 0                       Allen, Miss. Elisabeth Walton  211.3375
# 1                      Allison, Master. Hudson Trevor  151.5500
# 2                        Allison, Miss. Helen Loraine  151.5500
# 3                Allison, Mr. Hudson Joshua Creighton  151.5500
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500
# ...                                               ...       ...
# 1300          Yasbeck, Mrs. Antoni (Selini Alexander)   14.4542
# 1304                             Zabour, Miss. Hileni   14.4542
# 1306                        Zakarian, Mr. Mapriededer    7.2250
# 1307                              Zakarian, Mr. Ortin    7.2250
# 1308                               Zimmerman, Mr. Leo    7.8750
#
# [609 rows x 2 columns]

# %%
df['sex']=='female'
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %%
df.loc[(df['sex']=='female') & (df['age']<=30), 'name':'fare']
# Out:
#                                                    name     sex   age  sibsp  \
# 0                         Allen, Miss. Elisabeth Walton  female  29.0      0
# 2                          Allison, Miss. Helen Loraine  female   2.0      1
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0      1
# 11    Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 12                        Aubart, Mme. Leontine Pauline  female  24.0      0
# ...                                                 ...     ...   ...    ...
# 1267  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
# 1273                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 1279               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 1300            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0      1
# 1304                               Zabour, Miss. Hileni  female  14.5      1
#
#       parch    ticket      fare
# ...

# %% [markdown]
# **Data Visualisation**
#
# ---
#
#
#
# ---

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()

plt.show()

# %%
fig,ax = plt.subplots(nrows=2)
plt.show()

# %%
fig,ax = plt.subplots(ncols=2)
plt.show()

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(15,5))
plt.show()

# %%
x = [1,2,3,4,5,6,7,8]
y = [3,4,5,6,7,8,5,10]

# %%
fig,ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %%
fig,ax = plt.subplots(nrows=2,ncols=2)
ax[0,0].plot(x,y)
ax[0,1].pie(x)
ax[1,0].barh(x,y)
ax[1,1].scatter(x,y)
plt.show()

# %% [markdown]
# Encoding

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
X = df[['sex','age','embarked']]

# %%
X['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
X['embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
# Gender = Nominal
pd.get_dummies(X)
# Out:
#         age  sex_female  sex_male  embarked_C  embarked_Q  embarked_S
# 0     29.00           1         0           0           0           1
# 1      0.92           0         1           0           0           1
# 2      2.00           1         0           0           0           1
# 3     30.00           0         1           0           0           1
# 4     25.00           1         0           0           0           1
# ...     ...         ...       ...         ...         ...         ...
# 1304  14.50           1         0           1           0           0
# 1305    NaN           1         0           1           0           0
# 1306  26.50           0         1           1           0           0
# 1307  27.00           0         1           1           0           0
# 1308  29.00           0         1           0           0           1
#
# [1309 rows x 6 columns]

# %%
 X.replace({'embarked':{'C':2,'Q':1,'S':0}})
# Out:
#          sex    age  embarked
# 0     female  29.00       0.0
# 1       male   0.92       0.0
# 2     female   2.00       0.0
# 3       male  30.00       0.0
# 4     female  25.00       0.0
# ...      ...    ...       ...
# 1304  female  14.50       2.0
# 1305  female    NaN       2.0
# 1306    male  26.50       2.0
# 1307    male  27.00       2.0
# 1308    male  29.00       0.0
#
# [1309 rows x 3 columns]

# %%
X.replace({'sex':{'female':1,'male':0}})
# Out:
#       sex    age embarked
# 0       1  29.00        S
# 1       0   0.92        S
# 2       1   2.00        S
# 3       0  30.00        S
# 4       1  25.00        S
# ...   ...    ...      ...
# 1304    1  14.50        C
# 1305    1    NaN        C
# 1306    0  26.50        C
# 1307    0  27.00        C
# 1308    0  29.00        S
#
# [1309 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(10,4.5))
x = [170,170,160]
y = [80,80.5,80]
ax.plot(x,y)
plt.show()
